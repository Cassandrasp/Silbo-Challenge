# %%
# Data science
import pandas as pd
print(f"Pandas: {pd.__version__}")
import numpy as np
print(f"Numpy: {np.__version__}")

# Deep Learning 
import tensorflow as tf
print(f"Tensorflow: {tf.__version__}")
from tensorflow import keras
import sklearn
print(f"Sklearn: {sklearn.__version__}")

# NER
import spacy
print(f'spaCy: {spacy.__version__}')
import random
from spacy.training.example import Example
# Out:
# Pandas: 2.0.3
# Numpy: 1.24.3
# Tensorflow: 2.13.0
# Sklearn: 1.3.2
# spaCy: 3.7.4

# %%
frases_compra = [
"Quiero comprar una camiseta roja en talla S.",
"Estoy interesado en adquirir unos pantalones negros.",
"Deseo comprar un vestido azul en talla M.",
"Necesito comprar una chaqueta gris.",
"¿Cuánto cuesta una camisa verde en talla L?",
"¿Tienes sudaderas en negro?",
"Busco una falda azul.",
"Estoy buscando un jersey blanco.",
"Quiero comprar un abrigo gris.",
"¿Tienes shorts en azul?",
"¿Puedo comprar una bufanda verde?",
"¿Dónde puedo comprar un gorro rojo?",
"¿Tienes chalecos en negro?",
"¿Dónde puedo comprar un traje blanco?",
"¿Hay blusas azules disponibles?",
"¿Dónde puedo encontrar ponchos verdes?",
"Quiero comprar un cinturón negro.",
"¿Venden calcetines rojos?",
"¿Cuál es el precio de las camisetas rojas?",
"¿Tienen vestidos azules disponibles?",
"¿Puedes decirme qué materiales se usaron para hacer esa camiseta roja?",
"¿Podrías proporcionarme más detalles sobre los pantalones negros?",
"Me gustaría conocer más sobre el vestido azul en talla M, ¿tienes información adicional?",
"¿Cuál es la composición de la chaqueta gris que tienes en stock?",
"¿Tienes información sobre la camisa verde en talla L? Estoy interesado en saber más.",
"¿Puedes darme más detalles sobre las sudaderas negras que vendes?",
"Quiero saber más sobre la falda azul que tienes en tu tienda.",
"¿Puedes proporcionarme información detallada sobre el jersey blanco?",
"Me gustaría obtener más información sobre el abrigo gris que tienes en exhibición.",
"¿Tienes información adicional sobre los shorts azules que vendes?",
"¿Puedes decirme más sobre la bufanda verde que está en tu catálogo?",
"¿Dónde puedo encontrar información sobre los gorros rojos que vendes?",
"¿Podrías proporcionarme más detalles sobre los chalecos negros que tienes en existencia?",
"Quiero saber más sobre los trajes blancos que tienes en tu tienda.",
"¿Tienes información adicional sobre las blusas azules que vendes?",
"Me gustaría obtener más detalles sobre los ponchos verdes que tienes en stock.",
"¿Cuál es la información de los cinturones negros que tienes en tu tienda?",
"¿Podrías proporcionarme más detalles sobre los calcetines rojos que vendes?",
"¿Tienes información sobre los precios de las camisetas rojas que ofreces?",
"¿Puedes decirme más sobre los vestidos azules que tienes disponibles?",
"¿Puedes decirme quién es el vendedor de esta camiseta roja?",
"¿Quién es el proveedor de los pantalones negros que tienes en tu tienda?",
"¿Podrías proporcionarme más información sobre la tienda que vende el vestido azul en talla M?",
"Me gustaría conocer más sobre la empresa que suministra la chaqueta gris.",
"¿Quién es el fabricante de la camisa verde en talla L que vendes?",
"¿Puedes decirme más sobre la compañía que ofrece las sudaderas negras?",
"Quiero saber quién es el distribuidor de la falda azul que tienes en stock.",
"¿Podrías proporcionarme información sobre el proveedor del jersey blanco?",
"Me gustaría obtener más detalles sobre la empresa que fabrica el abrigo gris que tienes en exhibición.",
"¿Quién es el fabricante de los shorts azules que vendes?",
"¿Podrías decirme quién es el proveedor de la bufanda verde que está en tu catálogo?",
"¿Dónde puedo encontrar información sobre el proveedor de los gorros rojos que vendes?",
"Quiero saber más sobre la empresa que suministra los chalecos negros que tienes en existencia.",
"¿Quién es el proveedor de los trajes blancos que tienes en tu tienda?",
"¿Podrías proporcionarme más detalles sobre la compañía que ofrece las blusas azules que vendes?",
"Me gustaría obtener información sobre el distribuidor de los ponchos verdes que tienes en stock.",
"¿Quién es el fabricante de los cinturones negros que tienes en tu tienda?",
"¿Podrías decirme quién es el proveedor de los calcetines rojos que vendes?",
"Quiero conocer más sobre la empresa que suministra las camisetas rojas que ofreces.",
"¿Puedes proporcionarme información sobre el vendedor de los vestidos azules que tienes disponibles?"
]

# %%
len(frases_compra)
# Out:
# 60

# %%
acciones = [
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    1,  # Compra de la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    2,  # Pedir información sobre la prenda
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3,  # Pedir información del vendedor
    3  # Pedir información del vendedor
]

# %%
len(acciones)
# Out:
# 60

# %%
# Creamos el DataFrame
df = pd.DataFrame({'input': frases_compra, 'intent': acciones})

# Mostramos el DataFrame
df.head(60)
# Out:
#                                                 input  intent
# 0        Quiero comprar una camiseta roja en talla S.       1
# 1   Estoy interesado en adquirir unos pantalones n...       1
# 2           Deseo comprar un vestido azul en talla M.       1
# 3                 Necesito comprar una chaqueta gris.       1
# 4         ¿Cuánto cuesta una camisa verde en talla L?       1
# 5                         ¿Tienes sudaderas en negro?       1
# 6                               Busco una falda azul.       1
# 7                    Estoy buscando un jersey blanco.       1
# 8                      Quiero comprar un abrigo gris.       1
# 9                             ¿Tienes shorts en azul?       1
# 10                  ¿Puedo comprar una bufanda verde?       1
# 11                ¿Dónde puedo comprar un gorro rojo?       1
# 12                         ¿Tienes chalecos en negro?       1
# 13              ¿Dónde puedo comprar un traje blanco?       1
# ...

# %%
df.to_csv('frases_javi.csv', index=False)

# %%
# Inicializar un modelo de SpaCy
nlp = spacy.blank("es")

# %%
# Crear el pipeline de reconocimiento de entidades
ner = nlp.add_pipe("ner")

# %%
# Añadir las etiquetas al pipeline
ner.add_label("prenda")
ner.add_label("talla")
ner.add_label("color")
# Out:
# 1

# %%
data = {
        "Me gustaría comprar una camiseta roja en talla Medium.",
        "¿Qué colores tienes disponibles para las camisas?",
        "Quiero información sobre los pantalones disponibles.",
        "¿Cuál es el precio de los abrigos en tu tienda?",
        "¿Qué tallas tienes para los vestidos?",
        "Necesito ayuda para elegir una chaqueta adecuada.",
        "Estoy interesado en los zapatos de color negro.",
        "Me gustaría saber si tienes suéteres en stock.",
        "¿Cuál es la marca de los sombreros que vendes?",
        "¿Tienes bufandas en colores neutros?",
        "¿Puedo obtener más información sobre los accesorios?",
        "Quiero comprar una falda corta en talla Small.",
        "¿Puedo ver algunas opciones de camisetas?",
        "Quiero comprar una camiseta roja en talla Small.",
        "Estoy interesado en adquirir unos pantalones negros.",
        "Deseo comprar un vestido azul en talla Medium.",
        "Necesito comprar una chaqueta gris.",
        "¿Cuánto cuesta una camisa verde en talla Large?",
        "¿Tienes sudaderas en negro?",
        "Busco una falda azul.",
        "Estoy buscando un jersey blanco.",
        "Quiero comprar un abrigo gris.",
        "¿Tienes shorts en azul?",
        "¿Puedo comprar una bufanda verde?",
        "¿Dónde puedo comprar un gorro rojo?",
        "¿Tienes chalecos en negro?",
        "¿Dónde puedo comprar un traje blanco?",
        "¿Hay blusas azules disponibles?",
        "¿Dónde puedo encontrar ponchos verdes?",
        "Quiero comprar un cinturón negro.",
        "¿Venden calcetines rojos?",
        "¿Cuál es el precio de las camisetas rojas?",
        "¿Tienen vestidos azules disponibles?"
}

# %%
entidades = {
    "prenda": [
        "camiseta", "camisetas",
        "pantalón", "pantalones",
        "camisa", "camisas",
        "suéteres", "suéter",
        "chaqueta", "chaquetas",
        "falda", "faldas",
        "vestido", "vestidos",
        "sudadera", "sudaderas",
        "jersey", "jerséis",
        "abrigo", "abrigos",
        "shorts",
        "accesorios",
        "bufanda", "bufandas",
        "gorro", "gorros",
        "chaleco", "chalecos",
        "blusa", "blusas",
        "zapato", "zapatos",
        "poncho", "ponchos",
        "sombrero", "sombreros",
        "cinturón", "cinturones",
        "calcetín", "calcetines"
    ],
    "color": [
        "rojo", "rojos",
        "roja", "rojas",
        "azul", "azules",
        "negro", "negros",
        "negra", "negras",
        "verde", "verdes",
        "gris", "grises",
        "blanco", "blancos", 
        "blanca", "blancas", 
        "amarillo", "amarillos",
        "amarilla", "amarillas",
        "rosa", "rosas",
        "marrón", "marrones",
        "naranja", "naranjas",
        "celeste", "celestes",
        "añil", "añiles",
        "morado", "morados",
        "morada", "moradas"
    ],
    "talla": [
        "XS",
        "Small",
        "Medium",
        "Large",
        "XL"
    ]
}

# %%
# Cargar spaCy
nlp = spacy.load("es_core_news_sm")

# %%
# Definir la lista para almacenar los datos procesados
training_data = []

# Iterar sobre cada frase y generar los datos de entrenamiento
for utterance in data:
    doc = nlp(utterance)  # Procesar la frase con spaCy
    entities = []  # Lista para almacenar las entidades encontradas en la frase
    
    # Iterar sobre cada palabra en la frase
    for token in doc:
        # Buscar si la palabra está presente en alguna de las listas de entidades
        for label, keywords in entidades.items():
            if token.text.lower() in keywords:
                # Agregar la entidad encontrada al formato requerido por spaCy
                entities.append((token.idx, token.idx + len(token.text), label))
    
    # Almacenar los datos de la frase junto con las entidades encontradas
    training_data.append((utterance, {'entities': entities}))

# %%
TRAINING_DATA = training_data
TRAINING_DATA
# Out:
# [('Necesito ayuda para elegir una chaqueta adecuada.',
#   {'entities': [(31, 39, 'prenda')]}),
#  ('¿Puedo comprar una bufanda verde?',
#   {'entities': [(19, 26, 'prenda'), (27, 32, 'color')]}),
#  ('Quiero comprar un cinturón negro.',
#   {'entities': [(18, 26, 'prenda'), (27, 32, 'color')]}),
#  ('¿Cuál es el precio de los abrigos en tu tienda?',
#   {'entities': [(26, 33, 'prenda')]}),
#  ('¿Venden calcetines rojos?',
#   {'entities': [(8, 18, 'prenda'), (19, 24, 'color')]}),
#  ('¿Dónde puedo comprar un gorro rojo?',
#   {'entities': [(24, 29, 'prenda'), (30, 34, 'color')]}),
#  ('¿Dónde puedo comprar un traje blanco?', {'entities': [(30, 36, 'color')]}),
#  ('¿Qué colores tienes disponibles para las camisas?',
#   {'entities': [(41, 48, 'prenda')]}),
#  ('¿Tienes sudaderas en negro?',
#   {'entities': [(8, 17, 'prenda'), (21, 26, 'color')]}),
#  ('¿Tienen vestidos azules disponibles?',
#   {'entities': [(8, 16, 'prenda'), (17, 23, 'color')]}),
# ...

# %%
# Inicializar un modelo de SpaCy
nlp = spacy.blank("es")

# Crear el pipeline de reconocimiento de entidades
ner = nlp.add_pipe("ner")

# Añadir las etiquetas al pipeline
ner.add_label("PRENDA")
ner.add_label("TALLA")
ner.add_label("COLOR")

# Inicializar el optimizador
optimizer = nlp.begin_training()

# Entrenar el modelo
for epoch in range(10):
    random.shuffle(TRAINING_DATA)
    losses = {}
    for text, annotations in TRAINING_DATA:
        example = Example.from_dict(nlp.make_doc(text), annotations)
        nlp.update([example], drop=0.5, losses=losses)
    print(losses)
# Out:
# {'ner': 152.61745495488867}
# {'ner': 86.63781315623783}
# {'ner': 72.19046527652245}
# {'ner': 53.877904692764716}
# {'ner': 39.5238630596539}
# {'ner': 40.594646719643144}
# {'ner': 15.130601338263132}
# {'ner': 16.34128962231025}
# {'ner': 14.694661338431219}
# {'ner': 11.109084812760099}

# %%
# Guardar el modelo entrenado
nlp.to_disk("modelo_entrenado_spacy")

# Uso del modelo
# Cargar el modelo entrenado
nlp = spacy.load("modelo_entrenado_spacy")

# Texto de ejemplo para reconocer entidades
texto = "Estoy buscando un gorro azul en talla M."

# Procesar el texto con el modelo entrenado
doc = nlp(texto)

# Imprimir las entidades reconocidas en el texto
for ent in doc.ents:
    print(f"Nombre de la entidad:{ent.text}. Nombre de la etiqueta: {ent.label_}")
# Out:
# Nombre de la entidad:gorro. Nombre de la etiqueta: prenda
# Nombre de la entidad:azul. Nombre de la etiqueta: color
